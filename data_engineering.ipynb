# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/Life Expectancy Data 1.csv')
df2 = pd.read_csv('data/Life Expectancy Data 2.csv')
df3 = pd.read_csv('data/bmi_and_life_expectancy.csv')

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
# 3             69     0.01               78.184215         67.0      2787
# 4             71     0.01                7.097109         68.0      3013
#
#      ...      Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# ...

# %%
df.groupby(['Status']).count()
# Out:
#             Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# Status
# Developed       512   512               512              512            512
# Developing     2426  2426              2416             2416           2426
#
#             Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   \
# Status
# Developed       484                     512          339       512    512
# Developing     2260                    2426         2046      2426   2392
#
#               ...      Polio  Total expenditure  Diphtheria    HIV/AIDS   GDP  \
# Status        ...
# Developed     ...        512                480          512        512   448
# Developing    ...       2407               2232         2407       2426  2042
#
#             Population   thinness  1-19 years   thinness 5-9 years  \
# Status
# Developed          416                    512                  512
# Developing        1870                   2392                 2392
#
# ...

# %%
df = df.rename(columns={'Life expectancy ':'Life_Expectancy','Adult Mortality':'Adult_Mortality',
                   'infant deaths':'Infant_Deaths', 'percentage expenditure':'percentage_expenditure',
                  'Hepatitis B':'Hepatitis_B','Measles ':'Measles',' BMI ':'BMI',
                    'under-five deaths ':'under_five_deaths',' HIV/AIDS':'HIV_AIDS',
                  'Total expenditure':'Total_expenditure',' thinness  1-19 years':'thinness_1to19_years',
                  ' thinness 5-9 years':'thinness_5to9_years','Diphtheria ':'Diphtheria',
                  'Income composition of resources':'Income_composition_of_resources'})

# %%
df.count()
# Out:
# Country                            2938
# Year                               2938
# Status                             2938
# Life_Expectancy                    2928
# Adult_Mortality                    2928
# Infant_Deaths                      2938
# Alcohol                            2744
# percentage_expenditure             2938
# Hepatitis_B                        2385
# Measles                            2938
# BMI                                2904
# under_five_deaths                  2938
# Polio                              2919
# Total_expenditure                  2712
# Diphtheria                         2919
# HIV_AIDS                           2938
# GDP                                2490
# Population                         2286
# thinness_1to19_years               2904
# thinness_5to9_years                2904
# Income_composition_of_resources    2771
# Schooling                          2775
# dtype: int64

# %%
df = df[np.isfinite(df['Life_Expectancy'])]
df = df[np.isfinite(df['BMI'])]
# df = df[np.isfinite(df['Income_composition_of_resources'])]
# df = df[np.isfinite(df['GDP'])]
df.count()
# Out:
# Country                            2896
# Year                               2896
# Status                             2896
# Life_Expectancy                    2896
# Adult_Mortality                    2896
# Infant_Deaths                      2896
# Alcohol                            2720
# percentage_expenditure             2896
# Hepatitis_B                        2363
# Measles                            2896
# BMI                                2896
# under_five_deaths                  2896
# Polio                              2888
# Total_expenditure                  2684
# Diphtheria                         2888
# HIV_AIDS                           2896
# GDP                                2461
# Population                         2252
# thinness_1to19_years               2896
# thinness_5to9_years                2896
# Income_composition_of_resources    2736
# Schooling                          2736
# dtype: int64

# %%
df.to_csv('clean_data.csv')
